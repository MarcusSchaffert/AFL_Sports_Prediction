# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim
from mpl_toolkits.mplot3d import Axes3D
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
from sklearn import metrics
import torch.nn.functional as F
from sklearn.linear_model import LogisticRegression

# %%
torch.manual_seed(1)

# %%
cd C:\Users\Marcus\Desktop\python\alf_sports_betting_predictor
# Out:
# C:\Users\Marcus\Desktop\python\alf_sports_betting_predictor

# %%
df = pd.read_csv('2021_2020_afl_season_and_stats.csv')

# %%
df
# Out:
#      index         Home_Team  Home_Team_Score        Away_Team  \
# 0        0          Richmond              105          Carlton
# 1        1  Western Bulldogs               34      Collingwood
# 2        2          Essendon               63        Fremantle
# 3        3    Adelaide Crows               71     Sydney Swans
# 4        4        GWS Giants              105     Geelong Cats
# ..     ...               ...              ...              ...
# 202     49         Melbourne               82         Richmond
# 203     50         Fremantle               99  North Melbourne
# 204     51          Hawthorn              102   Adelaide Crows
# 205     52       Collingwood               85         Essendon
# 206     53     Port Adelaide               93         St Kilda
#
#      Away_Team_Score         home_Team        away_Team  home_Kicks  \
# 0                 81          Richmond          Carlton    0.290415
# 1                 86  Western Bulldogs      Collingwood    0.434907
# 2                 57          Essendon        Fremantle    0.296137
# 3                 74    Adelaide Crows     Sydney Swans    0.000000
# 4                 73        GWS Giants     Geelong Cats    0.527897
# ..               ...               ...              ...         ...
# 202               48         Melbourne         Richmond    0.668097
# 203               48         Fremantle  North Melbourne    0.380544
# 204               99          Hawthorn   Adelaide Crows    0.248927
# 205              109       Collingwood         Essendon    0.402003
# 206               39     Port Adelaide         St Kilda    0.765379
#
#      away_Kicks  home_Handballs  ...  home_Frees_Against  away_Frees_Against  \
# 0      0.775393        0.541276  ...            1.000000            0.515789
# 1      0.402003        1.000000  ...            0.000000            0.200000
# 2      0.380544        0.716698  ...            0.621053            0.305263
# 3      0.587983        0.497186  ...            0.589474            0.600000
# 4      0.782546        0.518762  ...            0.589474            0.715789
# ..          ...             ...  ...                 ...                 ...
# 202    0.290415        0.590994  ...            0.242105            1.000000
# 203    0.203147        0.542214  ...            0.305263            0.642105
# 204    0.000000        0.744841  ...            0.852632            0.589474
# 205    0.296137        0.633208  ...            0.200000            0.621053
# 206    0.650930        0.681051  ...            0.347368            0.336842
#
#      home_Goals  away_Goals  home_Behinds  away_Behinds  home_AFL_Fantasy  \
# 0      0.811111    0.666667      0.786667      0.773333          0.244397
# 1      1.000000    0.500000      1.000000      0.120000          0.798588
# 2      0.744444    0.488889      0.360000      0.680000          0.553270
# 3      0.544444    0.800000      0.560000      0.386667          0.000000
# 4      0.566667    0.955556      0.520000      0.666667          0.402825
# ..          ...         ...           ...           ...               ...
# 202    0.844444    0.811111      0.826667      0.786667          0.832668
# 203    0.488889    0.000000      0.680000      0.053333          0.347866
# 204    0.544444    0.544444      0.000000      0.560000          0.342340
# 205    0.500000    0.744444      0.120000      0.360000          0.529936
# 206    0.922222    0.755556      0.640000      0.373333          0.911268
#
#      away_AFL_Fantasy  home_win_lose  away_win_lose
# 0            0.459011            1.0            0.0
# 1            0.529936            0.0            1.0
# 2            0.347866            1.0            0.0
# 3            0.481732            0.0            1.0
# 4            1.000000            1.0            0.0
# ..                ...            ...            ...
# 202          0.244397            1.0            0.0
# 203          0.193430            1.0            0.0
# 204          0.000000            0.0            1.0
# 205          0.553270            1.0            0.0
# 206          0.517654            1.0            0.0
#
# [207 rows x 29 columns]

# %%
# adding home advantage and away advantage metrics 
mask = df
